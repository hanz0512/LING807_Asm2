# %% [markdown]
#                                                                             virginia Uhi & Han Zhang
#
#
# # Assignment 2 starter code
#
#
# This notebook contains code to run [coreferee](https://github.com/explosion/coreferee), a coreference system running under spaCy to extract coreference chains (or clusters) from text.
# To run the notebook, you first have to intall coreferee. See instructions here: https://spacy.io/universe/project/coreferee, but mostly what you need to do is, from a command prompt:
#
# `$ python -m pip install coreferee`
#
# `$ python -m coreferee install en`
#
# You'll also need to download the spaCy large language model and the transformer model for English. It turns out, spacy has just released new versions and coreferee is not yet compatible with them, so you need to download specific versions of each model:
#
# `$ python -m pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.0/en_core_web_lg-3.4.0.tar.gz`
#
# `$ python -m pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.4.0/en_core_web_trf-3.4.0.tar.gz`
#
# You can also run install these things by running the next two cells instead. You'll only need to do this once.

# %% [markdown]
# ## Part 1: Installation
#
# You only need to do this **once**, no matter how many times you modify this notebook. Or you can do it from the command prompt, with the commands above. There is no harm in doing in more than once; it just takes a very long time.
#
# The first cell installs coreferee and the English model for it (coreferee works for other languages too). The second cell installs the right versions of the English models for spaCy. You need these specific versions because newer versions of the English models don't work with coreferee.

# %%
# !python -m pip install coreferee
# !python -m coreferee install en

# %%
# !python -m pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.0/en_core_web_lg-3.4.0.tar.gz
# !python -m pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.4.0/en_core_web_trf-3.4.0.tar.gz

# %% [markdown]
# ## Part 2: Test coreferee

# %%
# import what we need, load the transformer model, 
# add coreferee to the spacy nlp pipeline

import coreferee, spacy
nlp = spacy.load('en_core_web_trf')
nlp.add_pipe('coreferee')

# %%
# this is just a test, so that you can see what the coreference chains look like
# you may get a CUDA warning here. As long as it's only a warning, things should run just fine

doc = nlp('Although he was very busy with his work, Peter had had enough of it. He and his wife decided they needed a holiday. They travelled to Spain because they loved the country very much.')

# %%
# now we print the coreference chains found

doc._.coref_chains.print()
# Out:
# 0: he(1), his(6), Peter(9), He(16), his(18)
# 1: work(7), it(14)
# 2: [He(16); wife(19)], they(21), They(26), they(31)
# 3: Spain(29), country(34)

# %% [markdown]
# A few things to note about the output:
#
# * We have 4 coreference chains, relating to: *Peter, work, wife(+Peter), Spain*
# * Coreferee is able to deal with cataphora, where the pronoun (*he*) appears before the referent (*Peter*)
# * Coreferee can deal with groups: *\[he+wife\], they*
# * The wife does not appear as an entity with a chain, because there is no referring expression to that entity. It only appears as part of *he and his wife*

# %%
# once we have an index for a particular referring expression, 
# we can ask coreferee to resolve it. For instance, printing
# the following expression gives us the referent for 
# the referring expression 31 (they)

print(doc._.coref_chains.resolve(doc[31]))
# Out:
# [Peter, wife]

# %% [markdown]
# ## Part 3: Run coreferee on local files

# %%
# do coreference chains for 5 documents in the data/ directory
# below is a sample for the first text

with open ("A1_data/5c1dbe1d1e67d78e2797d611.txt", "r", encoding='utf-8') as f:
    text0 = f.read()

# %%
doc0 = nlp(text0)

# %%
doc0._.coref_chains.print()
# Out:
# 0: couple(9), couple(76)
# 1: years(16), their(19)
# 2: letter(48), them(59), they(78)
# 3: Ayo(72), Ayo(150)
# 4: custody(87), it(96)
# 5: News(112), News(136)
# 6: fact(117), It(165)
# 7: orphanage(161), orphanage(206)
# 8: letter(171), letter(219)
# 9: Kim(174), Kim(211)
# 10: children(254), their(266)
# 11: adoption(300), adoption(333)
# 12: headlines(317), they(325)
# 13: Kim(338), Kim(401), Kim(425), her(437), she(452)
# 14: Nigeria(345), country(359)
# 15: papers(372), them(376)
# 16: Clark(395), Clark(432), He(444), him(478), him(486), him(496), he(501)
# 17: [Kim(401); son(404)], their(403)
# 18: Canada(474), They(484)
# 19: Nigeria(489), They(494)
# 20: Morans(561), Morans(602)
# 21: family(578), family(636), they(658), their(660), they(684)
# 22: government(589), it(598)
# 23: Kim(633), she(652), she(695)
# 24: agency(648), it(672)

# %%
# example: who does she(452) refer to?

print(doc0._.coref_chains.resolve(doc0[452]))
# Out:
# [Kim]

# %%
# print referring expressions that are people
# we are interested in those because they are the sources of quotes
for ent in doc0.ents:
    if ent.label_ in ["PERSON"]:
        print(ent.text, ent.label_)
# Out:
# Kim PERSON
# Clark Moran PERSON
# Ayo PERSON
# Kim PERSON
# Ayo PERSON
# Kim PERSON
# Clark PERSON
# Kim PERSON
# Ayo PERSON
# Morans PERSON
# Kim PERSON
# Ayo PERSON
# Clark PERSON
# Kim PERSON
# Kim PERSON
# Clark PERSON
# Ayo PERSON
# Kim PERSON
# Morans PERSON
# Ayo PERSON
# Kim PERSON
# Ben Miljure PERSON

# %% [markdown]
# ## TEXT1

# %%
#1 Text file
with open ("A1_data/5c1548a31e67d78e2771624f.txt", "r", encoding='utf-8') as f:
    text1 = f.read()

doc1 = nlp(text1)

# %%
doc1._.coref_chains.print()
# Out:
# 0: people(30), their(33)
# 1: Action(106), Action(174)
# 2: Some(145), they(158)
# 3: Canadians(205), Canadians(236)
# 4: rate(220), rate(246)
# 5: society(300), it(308)
# 6: Palvetzian(305), Palvetzian(336)
# 7: study(339), it(355)
# 8: their(351), million(364)
# 9: employers(402), their(407)
# 10: people(444), their(447)
# 11: study(468), study(511)
# 12: communication(565), it(569)
# 13: stereotype(581), it(600)
# 14: skills(609), they(613)
# 15: Palvetzian(625), Palvetzian(642)

# %%
# What does 'their' refers to

print(doc1._.coref_chains.resolve(doc1[33]))
# Out:
# [people]

# %% [markdown]
# ## TEXT2

# %%
#2 Text file
with open ("A1_data/5c182ac21e67d78e277944ad.txt", "r", encoding='utf-8') as f:
    text2 = f.read()

doc2 = nlp(text2)

# %%
doc2._.coref_chains.print()
# Out:
# 0: Lonechild(1), herself(12), her(18), she(42), She(75), She(87), her(91), Lonechild(111), she(113), her(115), her(123), she(158), Lonechild(162), She(181), she(214), she(221), Lonechild(225), she(227), she(274), Lonechild(278), she(280), she(327), She(360), she(373), Lonechild(388), Lonechild(403), Lonechild(407), her(411), She(417), she(419), Her(439), she(453), she(497), Lonechild(555), she(592), her(640), Lonechild(645), she(694)
# 1: future(197), future(232)
# 2: letter(305), they(315), they(337)
# 3: youth(343), it(345)
# 4: treatment(503), it(520), It(560)
# 5: people(531), they(536)
# 6: Council(665), it(669)

# %%
# what does 'her' in index0 refer to
print(doc2._.coref_chains.resolve(doc2[18]))
# Out:
# [Lonechild]

# %% [markdown]
# ## TEXT3

# %%
#3 Text file
with open ("A1_data/5c28972a795bd2fac69fa974.txt", "r", encoding='utf-8') as f:
    text3 = f.read()

doc3 = nlp(text3)

# %%
doc3._.coref_chains.print()
# Out:
# 0: party(3), its(13)
# 1: candidate(53), She(65)
# 2: Wang(111), she(118), Wang(149), she(152), she(154), she(165), she(202)
# 3: poem(117), poem(145), it(157)
# 4: Singh(162), He(184), He(192)
# 5: Wang(244), her(246)
# 6: Trudeau(271), Trudeau(301)
# 7: South(283), South(310)
# 8: Singh(353), he(362), Singh(391), he(394), he(409), his(416)
# 9: fears(368), they(383)
# 10: byelection(467), byelection(496)
# 11: Singh(472), he(477), he(481)
# 12: candidate(527), candidate(557)
# 13: Burnaby(616), country(621)

# %%
# what does "its" refer to
print(doc3._.coref_chains.resolve(doc3[13]))
# Out:
# [party]

# %% [markdown]
# ## TEXT4

# %%
#4 Text file
with open ("A1_data/5c29beda1e67d78e27b74939.txt", "r", encoding='utf-8') as f:
    text4 = f.read()

doc4 = nlp(text4)

# %%
doc4._.coref_chains.print()
# Out:
# 0: Australia(0), Australia(55)
# 1: Canadians(9), Canadians(86), Canadians(94)
# 2: China(12), country(16), China(83), China(97), China(143)
# 3: Payne(43), men(65)
# 4: Meng(201), She(226), her(310), she(317), She(337)
# 5: government(276), its(279)
# 6: China(290), China(371)
# 7: Canada(298), Canada(328)
# 8: concerns(301), them(304)
# 9: arrest(401), it(459)
# 10: Canada(446), Canada(465)
# 11: societies(539), their(571), their(596)
# 12: statement(560), it(626)
# 13: EU(563), EU(609)

# %%
# what does "their" refer to

print(doc4._.coref_chains.resolve(doc4[596]))
# Out:
# [societies]

# %% [markdown]
# ## TEXT5

# %%
#5 Text file
with open ("A1_data/5c489df91e67d78e271d66c5.txt", "r", encoding='utf-8') as f:
    text5 = f.read()

doc5 = nlp(text5)

# %%
doc5._.coref_chains.print()
# Out:
# 0: stretch(4), it(16)
# 1: Flames(10), Flames(33)
# 2: Backlund(22), Backlund(117)
# 3: break(58), break(144)
# 4: Rittich(202), his(215)
# 5: Calgary(225), Calgary(256)
# 6: Carolina(240), Carolina(275)
# 7: 1:54(263), it(273)
# 8: Hurricanes(289), their(303)
# 9: East(313), It(387)
# 10: Mrazek(317), He(332)
# 11: game(348), game(382)
# 12: teams(371), teams(394)
# 13: Jankowski(437), Jankowski(458), he(469), he(488)
# 14: corner(462), corner(505)
# 15: Mrazek(474), Mrazek(508), Mrazek(557)
# 16: Hurricanes(480), Hurricanes(522)
# 17: That(617), it(637)
# 18: opposite(640), they(645)
# 19: break(658), break(691)
# 20: Peters(684), Peters(707)
# 21: looks(749), them(758)

# %%
# What does 'it' refer to

print(doc5._.coref_chains.resolve(doc5[16]))
# Out:
# [stretch]

# %% [markdown]
# ## Side note: visualizations using another five text
# If you want to see this all in a much prettier format, you can use [displacy](https://spacy.io/usage/visualizers).

# %%
from spacy import displacy

# %% [markdown]
# ## TEXT6

# %%
# TEXT6

with open ("A1_data/5c286d031e67d78e27b3f17b.txt", "r", encoding='utf-8') as f:
    text6 = f.read()
    
doc6 = nlp(text6)

options = {"ents": ["PERSON"],
          "colors": {"PERSON": "lightsteelblue"}}

displacy.render(doc6, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A St. Louis-area man shot his girlfriend, her two young children and her mother in the home they all shared, authorities said Saturday. He exchanged gunfire with officers as he fled and was captured several hours later in a convenience store, covered in blood and wounded. </br> READ MORE: Man turns himself in after woman’s death in what Edmonton police suspect to be ‘domestic violence incident’. </br> Prosecutors filed 15 charges against
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Richard Darren Emery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of St. Charles, Missouri, including first-degree murder, assault and attempted robbery. Authorities said
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , 46, abandoned his own pickup and tried unsuccessfully to steal a woman’s car while on the run, attacking her as well. </br>
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  remained in a local hospital with two gunshot wounds that authorities said did not appear self-inflicted and most likely came from the shootout with officers. St. Charles County Prosecuting Attorney
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tim Lohmar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said investigators did not know the motive for the shootings as of Saturday evening. </br> “We may never know,”
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lohmar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said during a news conference. “This one in particular was the worst example of a domestic violence case. Anytime you have a domestic violence case you worry about the safety of the victim, and this would be your worst nightmare.”. </br> WATCH: ‘No magic pill’ – Toronto’s police chief highlights gun violence in year-end review. </br> St. Charles is a city of about 70,000 residents on the Missouri River northwest of St. Louis. Officials said it’s had of spate of deadly domestic violence incidents recently – with six deaths in the past eight days that
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lohmar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said are unrelated. </br> Officials said police received a call just before midnight Friday about a shooting at the house where
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and the victims lived.
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lohmar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said officers later found three victims dead of gunshot wounds in one bedroom. They were
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zoe Kasten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , 8; her brother,
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jonathan Kasten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , 10; and their grandmother,
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jane Moeckel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , 61. </br> Officers found the fourth victim, a 39-year-old woman, in the home’s master bedroom, suffering from gunshot wounds but still alive,
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lohmar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. She was taken to an area hospital, where she died. </br> READ MORE: Graphic details about death of 5-year-old
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Taliyah Marsman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  presented in Calgary double-murder trial. </br> Authorities did not name the fourth victim but described her as the children’s mother, the daughter of the older woman and
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s girlfriend. </br> The initial call came to police came from inside the house, and
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lohmar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said investigators believe
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Moeckel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  made it. </br> “During that phone call, the 911 operator could hear gunshots in the background,” St. Charles Police Lt.
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tom Wilkison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. </br>
# <mark class="entity" style="background: lightsteelblue; padding: 0.45em 0.

# %%
# We would like to use TEXT6 that also includes other type of entities all at once
# 


with open ("A1_data/5c286d031e67d78e27b3f17b.txt", "r", encoding='utf-8') as f:
    text6 = f.read()
    
doc6 = nlp(text6)

options = {"ents": ["PERSON", "ORG", "GPE"],  
           "colors": { "PERSON": "lightblue",
                        "ORG":  "lightyellow",
                        "GPE":  "lightgreen", }}



displacy.render(doc6, style="ent", options=options, jupyter=True)

# the data does not seem to be right, some of the data is mislabelled
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     St. Louis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -area man shot his girlfriend, her two young children and her mother in the home they all shared, authorities said Saturday. He exchanged gunfire with officers as he fled and was captured several hours later in a convenience store, covered in blood and wounded. </br> READ MORE: Man turns himself in after woman’s death in what
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Edmonton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  police suspect to be ‘domestic violence incident’. </br> Prosecutors filed 15 charges against
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Richard Darren Emery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     St. Charles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Missouri
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , including first-degree murder, assault and attempted robbery. Authorities said
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , 46, abandoned his own pickup and tried unsuccessfully to steal a woman’s car while on the run, attacking her as well. </br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  remained in a local hospital with two gunshot wounds that authorities said did not appear self-inflicted and most likely came from the shootout with officers.
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     St. Charles County
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Prosecuting Attorney
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tim Lohmar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said investigators did not know the motive for the shootings as of Saturday evening. </br> “We may never know,”
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lohmar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said during a news conference. “This one in particular was the worst example of a domestic violence case. Anytime you have a domestic violence case you worry about the safety of the victim, and this would be your worst nightmare.”. </br> WATCH: ‘No magic pill’ –
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Toronto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s police chief highlights gun violence in year-end review. </br>
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     St. Charles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is a city of about 70,000 residents on the Missouri River northwest of
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     St. Louis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . Officials said it’s had of spate of deadly domestic violence incidents recently – with six deaths in the past eight days that
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lohmar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said are unrelated. </br> Officials said police received a call just before midnight Friday about a shooting at the house where
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and the victims lived.
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lohmar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said officers later found three victims dead of gunshot wounds in one bedroom. They were
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zoe Kasten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , 8; her brother,
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jonathan Kasten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , 10; and their grandmother,
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jane Moeckel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , 61. </br> Officers found the fourth victim, a 39-year-old woman, in the home’s master bedroom, suffering from gunshot wounds but still alive,
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lohmar
#     <span style="fon

# %% [markdown]
# ## TEXT7

# %%
# let's continue with TEXT7

with open ("A1_data/5c287b841e67d78e27b4163e.txt", "r", encoding='utf-8') as f:
    text7 = f.read()
    
doc7 = nlp(text7)

options = {"ents": ["PERSON", "ORG", "GPE"],  
           "colors": { "PERSON": "lightblue",
                        "ORG":  "lightyellow",
                        "GPE":  "lightgreen", }}

displacy.render(doc7, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Erik Karlsson's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  two-game suspension didn't slow him down one bit. </br> The star defenceman had a season-high four points on a goal and three assists in his return as
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the San Jose Sharks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  beat the slumping
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Edmonton Oilers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  7-4 on Saturday. </br> &quot;It's nice to be back,&quot; said
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Karlsson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who received a two-game suspension for an illegal check to the head of
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Los Angeles Kings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  forward
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Austin Wagner
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . </br> &quot;It's never fun to be out of the lineup especially for the reason that I was out for — it was a little unjustified I think. But I made the most of it and I watched the games and sometimes it's good to watch the game from afar too, you figure a few things out. I was excited to get back today and do everything I could to stay in it and luckily it was only two [games].&quot;. </br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Logan Couture
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melker Karlsson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  each had two goals and
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joonas Donskoi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tomas Hertl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  also scored for the
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sharks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (21-12-7), who have won two in a row and pulled into a tie for top spot in
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Pacific Division
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  with
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Calgary Flames
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  entering Saturday night's action. </br>
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sharks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  head coach
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter DeBoer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said having
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Erik Karlsson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  back on the blue-line was a big boost. </br> &quot;You can see his impact on our team with the players around him,&quot;
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DeBoer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said of the former
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ottawa Senators
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  captain. &quot;You take him for granted a little bit, you realize when you take him out the hole is there and I think every week he's getting more comfortable here.&quot;. </br> Watch highlights of
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Edmonton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's loss to
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Jose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# :. </br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Logan Couture
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; li

# %% [markdown]
# ## TEXT8

# %%
# TEXT8

with open ("A1_data/5c49e1261e67d78e2721712b.txt", "r", encoding='utf-8') as f:
    text8 = f.read()
    
doc8 = nlp(text8)

options = {"ents": ["PERSON", "ORG", "GPE"],  
           "colors": { "PERSON": "lightblue",
                        "ORG":  "lightyellow",
                        "GPE":  "lightgreen", }}

displacy.render(doc8, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">. </br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Annabelle Liang
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Associated Press
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . </br> . </br> . </br>
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SINGAPORE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  -- World markets mostly rose Thursday as investors awaited comments from
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     European Central Bank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  President
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mario Draghi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  on the economic outlook. </br> KEEPING SCORE:
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's DAX gained 0.5 per cent to 11,130 and the CAC 40 in
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  rose 0.8 per cent to 4,878.
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Britain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's FTSE 100 was flat at 6,843. On Wall Street, the futures contract for the broad S&amp;P 500 index was up 0.1 per cent while that for the Dow Jones Industrial Average was steady. </br>
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ECB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  WATCH: The
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ECB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  wrapped up its first policy meeting of 2019. The bank said it did not change its interest rates or expectations for when rates might start rising. But investors will be looking to the tone of comments by
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Draghi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for clues as to how the
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ECB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is responding to weaker economic growth in Europe and beyond. </br> ANALYST'S TAKE: &quot;Will
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ECB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  President
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mario Draghi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  acknowledge the darkening clouds today? Lowering growth and inflation projections may provide a sell signal to the euro, but
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Draghi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's speech today may have even more impact on the single currency,&quot;
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hussein Sayed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Chief Market Strategist at
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FXTM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , said in a commentary. </br> THE DAY IN ASIA: Strong fourth-quarter earnings by big American companies like
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IBM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Proctor &amp; Gamble
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     United Technologies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  buoyed share prices in Asia. The Shanghai Composite index gained 0.4 per cent to 2,591.69 and
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     South Korea's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Kospi rose 0.8 per cent to 2,145.03.
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong's
#     <span style="font-size: 0.8e

# %% [markdown]
# ## TEXT9

# %%
# TEXT9

with open ("A1_data/5c483b26795bd2b724e92a68.txt", "r", encoding='utf-8') as f:
    text9 = f.read()
    
doc9 = nlp(text9)

options = {"ents": ["PERSON", "ORG", "GPE"],  
           "colors": { "PERSON": "lightblue",
                        "ORG":  "lightyellow",
                        "GPE":  "lightgreen", }}

displacy.render(doc9, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Nutrition experts say recommendations on beverages in the new Canada’s Food Guide will be felt most by young Canadians, as they are among the largest consumers of sugary beverages and have daily exposure to school-based nutrition programs. </br> The new guidelines recommend drinking water above all else. Low-fat milk is in the new guide, but in the broader protein category, and it is not given the prominence it had in the old guide, which featured dairy as a separate food group. </br> The move to emphasize water and limit the promotion of sugary beverages was expected, particularly after studies in recent years pointed to health risks associated with consuming even moderate amounts of sugar. In 2015,
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the World Health Organization
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  suggested people limit their consumption of “free” sugars – those added to foods and those that occur naturally in syrup, fruit juice, juice concentrate and honey – to less than 10 per cent of their daily calories. </br> Story continues below advertisement. </br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amanda Nash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , health promotion and nutrition manager with
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Heart and Stroke
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Manitoba
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , said the new recommendations on beverages are a welcome development, as many young people consume too much sugar in drinks. </br> “We do know that sugary drinks have little to no health benefits,” she said. “This is a really great place to start to help to support our youth at putting their health first and making healthier choices.”. </br> Many schools across
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  participate in programs from
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Dairy Farmers of Canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  that often promote the benefits of chocolate milk and other dairy products. For instance,
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alberta Milk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has a program called
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Club Moo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  that encourages elementary schools to offer white or chocolate milk to students up to five times a week. Beverage companies have also worked with schools to distribute juice to students, and used the product’s presence in the food guide in marketing and promotional materials. </br> But those practices may end or have to be changed to reflect the new guide. </br> “I think this will absolutely influence school food policy,&quot; said
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yoni Freedhoff
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , medical director of
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ottawa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bariatric Medical Institute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , who writes about food policy on his blog,
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Weighty Matters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . “This will provide public health advocates with a credible document to help influence change in their schools.”. </br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lee Finell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alberta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based health education manager with
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dairy Farmers of Canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , said she is unsure what direction school programs will go, but that her organization will continue to promote milk. “We’re still going to encourage its consumption, whether it’s at schools or at home,” she said. </br>
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Canadian Beverage Association
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said in a statement that 100-per-cent fruit juice “is a source of important vitamins and nutrients for Canadians who, across the board, aren’t consuming enough fruits and vegetables.” The statement also said that removing it from the diet could have “significant consequences on nutrient intakes.”. </br> Story continues below advertisement. </br> Story continues below advertisement. </br> In addition to water, the new food guide also suggests low-fat unsweetened mil

# %% [markdown]
# ## TEXT10

# %%
with open ("A1_data/5c52b36a1e67d78e273d029c.txt", "r", encoding='utf-8') as f:
    text10 = f.read()
    
doc10 = nlp(text10)

options = {"ents": ["PERSON", "ORG", "GPE"],  
           "colors": { "PERSON": "lightblue",
                        "ORG":  "lightyellow",
                        "GPE":  "lightgreen", }}

displacy.render(doc10, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SCOTTSDALE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ariz.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  –
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Phil Mickelson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is set for his 30th career appearance at the Waste Management Phoenix Open this week at TPC Scottsdale. </br> Once he tees off at 2:15 p.m. ET Thursday, he’ll be using the same strategy that’s helped him test the social media waters in recent months – stay out of trouble. </br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mickelson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  created a stir when unveiling his @PhilMickelson Twitter account, seemingly to help promote “The Match” against
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tiger Woods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Las Vegas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </br> But
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mickelson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has kept the banter going with a familiar sly tone. </br> “I didn’t realize what a great way it was to engage, connect and interact with people,”
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mickelson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. “It’s really been a fun experience for me and I’m glad I’m doing it.”. </br> There’s just one catch. </br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mickelson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  admitted his tweets need to be approved before they go out, denying the really juicy stuff to the general public but keeping his image intact. </br> “I have to be careful,”
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mickelson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. “I do have a buffer, if you will, because we all know I say and do things that sometimes are just stupid. So I have a buffer where I do all the stuff myself, send it to somebody, have it checked to make sure that there’s nothing in there that shouldn’t be.”. </br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mickelson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  obviously isn’t alone in this practice, so at least he admits it. We’d just love to know which tweets and posts have been scraped along the way. </br> “It’s not like I just get on and send something,”
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mickelson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. “I have to send it to somebody else, have two people check it just to make sure that I’m not making some of the mistakes that I made in the past as a way of trying to protect myself from the negative of it.”. </br> There shouldn’t be much negativity in
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mickelson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s world this week. The
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arizona State
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  grad is beloved around TPC Scottsdale and thrives in the crazy environment. He’s coming off a surprising T-2 after the 54-hole lead got away from him at the Desert Classic as he ramps up for 2019, a year
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mickelson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  thinks could be one of his best at age 48. </br> He already has 43
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PGA Tour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  wins and essentially guaranteed he would get to 50 career victories with his comments after winning the 2018 WGC-Mexico Championship. </br> That led to another interesting revelation from
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mickelson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  on Wednesday, when he said he might have gotten a little out over his skis. </br> “I really thought that after having won there, after playing three or four weeks heading into that tournament, that I was going to have a stellar end to the season,”
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mickelson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. “That was a bit disappointing. I’ve got

# %% [markdown]
# ## Part 4: Run the quote extraction from Assignment 1
# I suggest using the Matcher quote extraction system from A1, but, if you implemented your own version, or improved on this one, feel free to use that instead.

# %%
#import what we need for this
from spacy.matcher import Matcher

matcher = Matcher(nlp.vocab)

# %%
# run the matcher for text1

matcher = Matcher(nlp.vocab)

pattern_S_Q_A = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "+"}, 
                 #{"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 {'IS_PUNCT': True, "OP": "*"},
                 {'ORTH': '"'},
                 {'POS': "PRON", "OP": "+" }, 
                 # {'POS': "VERB"},
                 {'IS_ALPHA': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]  

pattern_S_Q_B = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "+"}, 
                 # {"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 # {'IS_PUNCT': True, "OP": "*"},
                 # {'ORTH': '"'},
                 #{'POS': "VERB"},
                 {'POS': "PROPN", "OP": "+" },
                 {'POS': "VERB"},
                 #{'POS': "VERB"}
                 #{'IS_ALPHA': True, "OP": "+"},
                 # {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]
pattern_S_Q_C = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "*"}, 
                 #{"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 {'IS_PUNCT': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "+"},
                 {'ORTH': '"'},
                 {'POS': "PRON", "OP": "+" }, 
                 # {'POS': "VERB"},
                 {'IS_ALPHA': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]  

matcher.add("QUOTES_S_Q", [pattern_S_Q_A, pattern_S_Q_B, pattern_S_Q_C], greedy = 'LONGEST')
doc = nlp(text1)
matches = matcher(doc)
#matches.sort (key = lambda x:x[1])
print(len(matches))

for match in matches[:10]:
    print(match, doc[match[1]:match[2]])
    print("\n") #blank space between outputs
# Out:
# 0

# %%
# run the matcher for text2

matcher = Matcher(nlp.vocab)

pattern_S_Q_A = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "+"}, 
                 #{"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 {'IS_PUNCT': True, "OP": "*"},
                 {'ORTH': '"'},
                 {'POS': "PRON", "OP": "+" }, 
                 # {'POS': "VERB"},
                 {'IS_ALPHA': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]  

pattern_S_Q_B = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "+"}, 
                 # {"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 # {'IS_PUNCT': True, "OP": "*"},
                 # {'ORTH': '"'},
                 #{'POS': "VERB"},
                 {'POS': "PROPN", "OP": "+" },
                 {'POS': "VERB"},
                 #{'POS': "VERB"}
                 #{'IS_ALPHA': True, "OP": "+"},
                 # {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]

pattern_S_Q_C = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "*"}, 
                 #{"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 {'IS_PUNCT': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "+"},
                 {'ORTH': '"'},
                 {'POS': "PRON", "OP": "+" }, 
                 # {'POS': "VERB"},
                 {'IS_ALPHA': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]  

matcher.add("QUOTES_S_Q", [pattern_S_Q_A, pattern_S_Q_B, pattern_S_Q_C], greedy = 'LONGEST')
doc = nlp(text2)
matches = matcher(doc)
#matches.sort (key = lambda x:x[1])
print(len(matches))

for match in matches[:10]:
    print(match, doc[match[1]:match[2]])
    print("\n") #blank space between outputs
# Out:
# 1
# (14911067671772931984, 677, 697) "As young people we understand that this land is foundational to who we are," she said.

# %%
# run the matcher for text3

matcher = Matcher(nlp.vocab)

pattern_S_Q_A = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "+"}, 
                 #{"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 {'IS_PUNCT': True, "OP": "*"},
                 {'ORTH': '"'},
                 {'POS': "PRON", "OP": "+" }, 
                 # {'POS': "VERB"},
                 {'IS_ALPHA': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]  

pattern_S_Q_B = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "+"}, 
                 # {"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 # {'IS_PUNCT': True, "OP": "*"},
                 # {'ORTH': '"'},
                 #{'POS': "VERB"},
                 {'POS': "PROPN", "OP": "+" },
                 {'POS': "VERB"},
                 #{'POS': "VERB"}
                 #{'IS_ALPHA': True, "OP": "+"},
                 # {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]

pattern_S_Q_C = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "*"}, 
                 #{"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 {'IS_PUNCT': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "+"},
                 {'ORTH': '"'},
                 {'POS': "PRON", "OP": "+" }, 
                 # {'POS': "VERB"},
                 {'IS_ALPHA': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]  

matcher.add("QUOTES_S_Q", [pattern_S_Q_A, pattern_S_Q_B, pattern_S_Q_C], greedy = 'LONGEST')
doc = nlp(text3)
matches = matcher(doc)
#matches.sort (key = lambda x:x[1])
print(len(matches))

for match in matches[:10]:
    print(match, doc[match[1]:match[2]])
    print("\n") #blank space between outputs
# Out:
# 0

# %%
# run the matcher for text4

matcher = Matcher(nlp.vocab)

pattern_S_Q_A = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "+"}, 
                 #{"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 {'IS_PUNCT': True, "OP": "*"},
                 {'ORTH': '"'},
                 {'POS': "PRON", "OP": "+" }, 
                 # {'POS': "VERB"},
                 {'IS_ALPHA': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]  

pattern_S_Q_B = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "+"}, 
                 # {"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 # {'IS_PUNCT': True, "OP": "*"},
                 # {'ORTH': '"'},
                 #{'POS': "VERB"},
                 {'POS': "PROPN", "OP": "+" },
                 {'POS': "VERB"},
                 #{'POS': "VERB"}
                 #{'IS_ALPHA': True, "OP": "+"},
                 # {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]

pattern_S_Q_C = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "*"}, 
                 #{"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 {'IS_PUNCT': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "+"},
                 {'ORTH': '"'},
                 {'POS': "PRON", "OP": "+" }, 
                 # {'POS': "VERB"},
                 {'IS_ALPHA': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]  

matcher.add("QUOTES_S_Q", [pattern_S_Q_A, pattern_S_Q_B, pattern_S_Q_C], greedy = 'LONGEST')
doc = nlp(text4)
matches = matcher(doc)
#matches.sort (key = lambda x:x[1])
print(len(matches))

for match in matches[:10]:
    print(match, doc[match[1]:match[2]])
    print("\n") #blank space between outputs
# Out:
# 0

# %%
# run the matcher for text5

matcher = Matcher(nlp.vocab)

pattern_S_Q_A = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "+"}, 
                 #{"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 {'IS_PUNCT': True, "OP": "*"},
                 {'ORTH': '"'},
                 {'POS': "PRON", "OP": "+" }, 
                 # {'POS': "VERB"},
                 {'IS_ALPHA': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]  

pattern_S_Q_B = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "+"}, 
                 # {"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 # {'IS_PUNCT': True, "OP": "*"},
                 # {'ORTH': '"'},
                 #{'POS': "VERB"},
                 {'POS': "PROPN", "OP": "+" },
                 {'POS': "VERB"},
                 #{'POS': "VERB"}
                 #{'IS_ALPHA': True, "OP": "+"},
                 # {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]
pattern_S_Q_C = [{'ORTH': '"'},
                 {'IS_ALPHA': True, "OP": "*"}, 
                 #{"ORTH":{"IN": [".","!", "?", ",", ";"]}},
                 {'IS_PUNCT': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "+"},
                 {'ORTH': '"'},
                 {'POS': "PRON", "OP": "+" }, 
                 # {'POS': "VERB"},
                 {'IS_ALPHA': True, "OP": "+"},
                 {'IS_PUNCT': True, "OP": "*"},
                 #{'ORTH': '"'}
                 ]  

matcher.add("QUOTES_S_Q", [pattern_S_Q_A, pattern_S_Q_B, pattern_S_Q_C], greedy = 'LONGEST')
doc = nlp(text5)
matches = matcher(doc)
#matches.sort (key = lambda x:x[1])
print(len(matches))

for match in matches[:10]:
    print(match, doc[match[1]:match[2]])
    print("\n") #blank space between outputs
# Out:
# 3
# (14911067671772931984, 727, 754) "We played the best when the game was on the line in the third and I thought we had some great looks that made Mrazek make
#
#
# (14911067671772931984, 706, 726) " Peters said. "I like the direction which we are trending and the contributions throughout the lineup.
#
#
# (14911067671772931984, 350, 356) " Carolina coach Rod Brind'Amour said

# %% [markdown]
# ## Your turn
#
# Check instructions on Canvas for what to do and what to submit.
